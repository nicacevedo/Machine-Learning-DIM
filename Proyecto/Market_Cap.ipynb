# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

market_cap2 = []
dates = []
i = 0
for mc in market_cap:
    for cap in mc.split(' '):
        if len(cap) > 0:
            i+=1
            if i%2 == 0:
                market_cap2.append(-float(cap)) 
            else:
                dates.append(float(cap))


# market_cap2 = np.array(market_cap2)  - min(market_cap2) #27.96438363433407 # + 858.5 +

# dates

# # DataFrame
df = pd.DataFrame(market_cap2, columns=['Market Cap'])

dates = [datetime(2016,6,10) + timedelta(i) for i in range(0,df.shape[0]*7,7)]
dates[3] = datetime(2016,6,27) # 27 de junio se agrega
# print(dates)
dates2 = [datetime(2016,6,28) + timedelta(i) for i in range(0,(df.shape[0]-211)*7,7)] # 28 no, pero es 27 

# df.loc[df['Time'] > datetime(2016,6,28),'Time'] = dates2[:100]
dates = dates[:4] + dates2[1:]


dates2 = [datetime(2017, 6, 28) + timedelta(i) for i in range(0,(df.shape[0]-211)*7,7)]
dates = dates + dates2[1:]

dates2 = [datetime(2018, 7, 5) + timedelta(i) for i in range(0,(df.shape[0]-244)*7,7)]
dates = dates + dates2

dates2 = [datetime(2018, 11, 23) + timedelta(i) for i in range(0,(df.shape[0]-243)*7,7)]
dates = dates + dates2

dates2 = [datetime(2019, 4, 22) + timedelta(i) for i in range(0,(df.shape[0]-259)*7,7)]
dates = dates + dates2

dates2 = [datetime(2019, 5, 28) + timedelta(i) for i in range(0,(df.shape[0]-157)*7,7)]
dates = dates + dates2
dates.append(datetime(2021, 6, 11))

# df['Time'] = dates

# df.head()
# datetime(2019, 5, 27
# dates2
# df.head()

# # Date
# date = [datetime(2016,6,10) + timedelta(i) for i in range(0,df.shape[0],7)]
# date


# # Market Cap de BABA
# import matplotlib.pyplot as plt
# plt.figure(figsize=(15,6))
# plt.plot([i for i in range(len(market_cap2))], market_cap2)
# plt.show()

# %% [markdown]
# $\pi_t =$ Probabilidad de que una acción sea

# %%
# len(dates)
factor = (858.5 - 183.64)/(-(min(market_cap2) - max(market_cap2)))
mc = factor*df['Market Cap'] - min(factor*df['Market Cap']) + 183.64
df = pd.DataFrame(mc[1:-1], columns=['Market Cap'])
# min(mc), max(mc)


df['Date'] = dates
df.head()
# Out:
#    Market Cap       Date
# 1  187.820959 2016-06-10
# 2  190.492814 2016-06-17
# 3  188.736316 2016-06-24
# 4  183.640000 2016-06-27
# 5  197.425400 2016-07-05

# %%
# plt.figure()
df.plot(x='Date', figsize=(15,6))
plt.show()

# %%
import yfinance as yf
from datetime import date

# Ticker
ticker = 'BABA'

# Año inicial
anho = 2016

df2 = yf.download(ticker, start=f"{anho}-01-10", end=date.today()).reset_index().round(2)
df2.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date   Open   High    Low  Close  Adj Close    Volume
# 0 2016-01-11  71.29  71.73  69.02  69.92      69.92  16961400
# 1 2016-01-12  71.45  72.77  71.00  72.68      72.68  13456000
# 2 2016-01-13  72.77  73.24  70.22  70.29      70.29  12480200
# 3 2016-01-14  70.29  72.72  68.27  72.25      72.25  17719600
# 4 2016-01-15  68.70  71.00  67.54  69.59      69.59  20722500

# %%
df3 = df2.merge(df, on='Date', how='inner')
df3.shape
# Out:
# (261, 8)

# %%
df3.head()
# Out:
#         Date   Open   High    Low  Close  Adj Close    Volume  Market Cap
# 0 2016-06-10  76.43  77.05  75.76  75.92      75.92  10421100  187.820959
# 1 2016-06-17  78.45  78.45  76.48  77.00      77.00  15582600  190.492814
# 2 2016-06-24  76.83  77.50  75.43  76.29      76.29  18224800  188.736316
# 3 2016-06-27  75.80  75.97  73.30  74.23      74.23  15131300  183.640000
# 4 2016-07-05  79.04  79.55  78.37  78.97      78.97   6845200  197.425400

# %%
df3['Total Volume'] = df3['Market Cap'] / df3['Close']
df3.plot(x = 'Date', y = 'Total Volume', figsize=(15,6))
plt.show()

# %%
df = df3

# Precio de cierre
close_price = df.Close.to_numpy()

# Lags temporales (t-1)
df.loc[1:, 'Lags'] = close_price[:-1]

# Diferencia común
df['Diff'] = df['Close'] - df['Lags']

# Diferencia porcentual
df['Per_Diff'] = (df['Close'] - df['Lags'])/df['Lags']
df.head()
# Out:
#         Date   Open   High    Low  Close  Adj Close    Volume  Market Cap  \
# 0 2016-06-10  76.43  77.05  75.76  75.92      75.92  10421100  187.820959
# 1 2016-06-17  78.45  78.45  76.48  77.00      77.00  15582600  190.492814
# 2 2016-06-24  76.83  77.50  75.43  76.29      76.29  18224800  188.736316
# 3 2016-06-27  75.80  75.97  73.30  74.23      74.23  15131300  183.640000
# 4 2016-07-05  79.04  79.55  78.37  78.97      78.97   6845200  197.425400
#
#    Total Volume   Lags  Diff  Per_Diff
# 0      2.473933    NaN   NaN       NaN
# 1      2.473933  75.92  1.08  0.014226
# 2      2.473933  77.00 -0.71 -0.009221
# 3      2.473932  76.29 -2.06 -0.027002
# 4      2.500005  74.23  4.74  0.063856

# %%
from scipy.optimize import minimize, rosen, rosen_der

P_t   = df['Close'].to_numpy()
P_t_1 = df['Lags'].to_numpy()


def ll(θ_σ):

    θ = θ_σ[0]
    σ = θ_σ[1]

    # 
    return  np.sum( ( P_t - P_t_1 * (1+θ) )**2 )

# Parámetros iniciales
θ_σ = [0.5,1]


# Optimización
res = minimize(ll, θ_σ, method='nelder-mead',
               options={'xatol': 1e-8, 'disp': True})

print()
print('θ óptimo:',res.x[0])
# Out:
# ...
#
# θ óptimo: 0.5

# %%
( P_t - P_t_1 )#(1 + θ) )**2
# Out:
# array([   nan,   1.08,  -0.71,  -2.06,   4.74,   2.77,   1.03,   0.82,
#          0.21,   1.44,  11.42,  -0.87,   0.21,   7.78,  -3.5 ,   1.08,
#          6.9 ,  -2.81,  -0.22,  -1.89,   0.88,  -3.07,  -1.3 ,  -8.85,
#          2.21,   1.78,  -4.59,   1.76,  -2.32,  -2.3 ,   1.06,   8.15,
#         -0.63,   5.31,  -0.12,  -0.48,   0.76,   0.53,   0.78,  -0.27,
#          1.62,   0.84,   2.71,  -0.28,   2.92,   0.79,   4.25,   2.61,
#          1.91,   4.02,  -1.09,   0.98,   0.71,  11.98,   1.78,   3.15,
#          3.34,   4.13,   4.15,   2.64,  -3.88,   5.58,   2.01,  16.3 ,
#         -4.55,  -3.11,  10.83,  -1.02,  -6.96,   7.72,   5.98,  -5.08,
#         -9.39,  15.86,  -0.18,  -4.42,   8.36,  -9.93,  -7.28,   3.84,
#         -3.83,   0.33,  11.03,   5.79,  -5.96,  11.7 ,   8.76, -23.99,
#          6.46,   2.06,  -2.68,   2.91,   3.51,   2.74, -16.39,  -6.84,
#          3.29,   7.32, -12.46,  11.23,  13.98,   2.68,  -1.31,   1.18,
# ...

# %% [markdown]
# $\theta, \mu, \sigma$
